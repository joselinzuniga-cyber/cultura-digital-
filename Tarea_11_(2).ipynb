# %% [markdown]
# # Tarea: Uso de Condicionales (if / else)

# %% [markdown]
# ## Parte 1: Condicionales en la vida diaria
# Escribe 3 oraciones de situaciones reales donde usarías un "si... entonces...".
#
# Ejemplo:
# Si me despierto tarde, entonces llego tarde a la escuela.
#
# 1.Si no desayuno, entonces tengo hambre durante la mañana.
#
# 2.Si hace calor, entonces uso ropa ligera.
#
# 3.Si estudio para el examen, entonces saco una buena nota.

# %% [markdown]
# ## Parte 2: Explicación de la importancia de las condicionales
# Explica 4 ejemplos donde se vea por qué son necesarias las condicionales.
#
# Ejemplo modelo:
#
#
# *   Situación: Decidir si llevo paraguas.
# *   Condición: Si está lloviendo.
# *   Si se cumple: Llevo paraguas.
# *   Si no se cumple: Salgo sin paraguas.
#
#
#
# 1.
# *   Situación:Decidir si llevo abrigo.
# *   Condición:Si hace frío.
# *   Si se cumple:Llevo abrigo.
# *   Si no se cumple:Salgo con ropa ligera.
#
# 2.
# *   Situación:Elegir transporte.
# *   Condición:Si el autobús llega tarde.
# *   Si se cumple:Tomo un taxi.
# *   Si no se cumple:Subo al autobús como siempre.
#
# 3.
# *   Situación:: Preparar una comida.
# *   Condición:Si tengo todos los ingredientes.
# *   Si se cumple:Cocino la receta completa.
# *   Si no se cumple:Busco otra receta o voy a comprar.
#
# 4.
# *   Situación:Ir al gimnasio.
# *   Condición:Si termino mis tareas temprano.
# *   Si se cumple:Voy al gimnasio.
# *   Si no se cumple:Me quedo en casa terminando el trabajo.

# %% [markdown]
# ## Parte 3: Condicionales en Python

# %% [markdown]
# ### Ejercicio 1
# Pide la hora (0-23). Si es menor que 12 muestra 'Es mañana', si no 'Es tarde o noche'.

# %%
# Escribe tu código aquí
hora = int(input("Ingresa la hora (0-23): "))

if hora < 12:
    print("Es mañana")
else:
    print("Es tarde o noche")
# Out:
# Ingresa la hora (0-23): 2
# Es mañana

# %% [markdown]
# ### Ejercicio 2
# Pide dos números y muestra cuál es mayor o si son iguales.

# %%
# Escribe tu código aquí
num1 = float(input("Ingresa el primer número: "))
num2 = float(input("Ingresa el segundo número: "))

if num1 > num2:
    print("El primer número es mayor.")
elif num2 > num1:
    print("El segundo número es mayor.")
else:
    print("Los dos números son iguales.")
# Out:
# Ingresa el primer número: 10
# Ingresa el segundo número: 56
# El segundo número es mayor.

# %% [markdown]
# ### Ejercicio 3
# Pide un número entero y muestra si es par o impar.

# %%
# Escribe tu código aquí
numero = int(input("Ingresa un número entero: "))

if numero % 2 == 0:
    print("El número es par.")
else:
    print("El número es impar.")
# Out:
# Ingresa un número entero: 56
# El número es par.
